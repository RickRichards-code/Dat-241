# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from scipy.sparse import csr_matrix

image = cv2.imread("img/wallpaperflare.com_wallpaper.jpg", cv2.IMREAD_GRAYSCALE)

plt.imshow(image, cmap='gray')
plt.title('Imagen en Escala de Grises')
plt.show()

# print(image[:10, :10]) 

print("dimensiones de la imagen:", image.shape)

matriz = 'matrizSparce.csv'
np.savetxt(matriz, image, delimiter=',', fmt='%d')
# Out:
# dimensiones de la imagen: (1080, 1920)
