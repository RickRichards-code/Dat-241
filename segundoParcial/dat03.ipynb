# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from scipy.sparse import csr_matrix

img1 = cv2.imread("img/wallpaperflare.com_wallpaper (1).jpg", 0)
img2 = cv2.imread("img/wallpaperflare.com_wallpaper (3).jpg", 0)

img3 = cv2.addWeighted(img1, 0.5, img2, 0.5, 0)
img4 = cv2.subtract(img1, img2)

plt.imshow(img1)
plt.title("imagen - 1")
plt.show()

plt.imshow(img2)
plt.title("imagen - 2")
plt.show()

plt.imshow(img3)
plt.title("imagen - 3 (adiccion)")
plt.show()

plt.imshow(img3)
plt.title("imagen - 4 (resta)")
plt.show()
