# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from scipy.sparse import csr_matrix

img1 = cv2.imread("img/wallpaperflare.com_wallpaper.jpg", 0)
plt.imshow(img1)
plt.title("imagen - 1")
plt.show()
